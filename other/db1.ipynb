# %%
import pandas as pd
import numpy as np
import random

df = pd.read_csv('db.csv')

df.drop(columns=['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',\
                'Tax 5%', 'Payment', 'cogs', 'gross margin percentage',\
                'gross income', 'Rating', 'Total'], inplace=True)

df['transacciones'] = df.index

df.rename(columns={'Product line': 'Categoria', 'Unit price':'Precio',\
                   'Quantity': 'Cantidad', 'Date': 'Fecha', 'Time':'Hora',\
                   }, inplace=True)

columnas = ['Fecha', 'Hora', 'transacciones', 'Categoria',\
           'Precio', 'Cantidad']

df = df[columnas]

df['Total'] = df['Precio'] * df['Cantidad']

health_and_beauty = ['aftershave', 'cera', 'rastrillo', 'talco', 'desodorante',\
                     'pasta dental', 'crema', 'esponja', 'jabon exfoliante',\
                     'shampoo', 'acondicionador', 'desmaquillante', 'blush',\
                     'polvo traslucido', 'base', 'aceite corporal', 'gel',\
                     'spray', 'pinzas', 'sales']

electronic = ['xbox', 'playstation', 'wi', 'pantalla', 'video proyector',\
              'blu-ray', 'soundbar', 'home theater', 'laptop', 'monitor',\
              'mouse', 'microfono', 'teclado', 'celular', 'audifonos',\
              'auxiliar', 'hdmi', 'cable fibra optica', 'pilas', 'modem',\
              'repetidor', 'despertador', 'ipad', 'tablet', 'google home',\
              'alexa', 'chrome cast', 'apple tv', 'cargador', 'extension',\
              'radio', 'airpods', 'mouse pad', 'oculus rift', 'usb']

home_and_life = ['lavadora', 'secadora', 'plancha', 'mesa', 'silla',\
                 'aspiradora', 'abre corchos', 'refrigerador', 'ollas',\
                 'cubiertos', 'tapete', 'tostador', 'cubiertos', 'cuchillos',\
                 'horno', 'toallero', 'copas', 'vasos', 'tetera', 'alfombra',\
                 'cafetera', 'gaveta', 'toalla', 'bolsa', 'maleta', 'bascuala']

sports = ['tienda de campaña', 'silla de acampar', 'bolsa de esqui', 'mochila',\
          'pesa rusa', 'tapete yoga', 'arrow grip', 'rodillo de espuma',\
          'asas', 'set voleyball', 'set de pesas', 'tapete para ejercicio',\
          'paracaidas entrenador', 'chaleco de peso', 'rueda abdominal',\
          'balon medicinal', 'pull up bar', 'escalera agilidad',\
          'porteria', 'hamaca de camping', 'lona de camping', 'raqueta',\
          'sleeping', 'set herradura', 'cuerda de entrenamiento']

food = ['ginebra', 'coctel de frutas', 'mayonesa', 'cafe', 'arroz', 'mate',\
        'whisky', 'vinagre', 'endulzante', 'nueces', 'licor de manzana',\
        'coca cola', 'cerveza', 'piña', 'te verde', 'miel de fruta',\
        'tequila', 'almendra entera', 'cacahuates', 'leche', 'harina',\
        'galletas', 'harina de coco', 'jugo verde', 'pasta', 'chilorio',\
        'vodka', 'mermelada', 'jugo sazonador', 'frijoles', 'aceite cocina']

fashion = ['removedor de espinillas', 'cosmetiquera', 'bolsa de aseo',\
           'lampara led', 'organizador de maquillaje', 'mascara facial',\
           'diademas', 'manicure personal', 'estuche de belleza',\
           'set de baño', 'bolsa organizadora', 'peluca', 'depiladora',\
           'lifting', 'pop-up sheets', 'paño de algodon', 'bandas cabeza']

categorics = {'Health and beauty': health_and_beauty,\
              'Electronic accessories': electronic,\
              'Home and lifestyle': home_and_life,\
              'Sports and travel': sports,\
              'Food and beverages': food,\
              'Fashion accessories': fashion}

new = df.copy()
lista =[]
for i in new['Categoria']:
    if i in categorics.keys():
         lista.append(random.choice(categorics[i]))

new['Productos'] = lista

new['Fecha'] = new['Fecha'].astype('datetime64[ns]')
new['Hora'] = new['Hora'].astype('datetime64[ns]')
new['Hora'] = new['Hora'].dt.hour
new['Dia'] = new['Fecha'].dt.day_name()



sales_per_hour = new['Hora'].value_counts()
sales_per_day = new['Dia'].value_counts()
total_sales = new['Total'].sum()

# %%
new['Productos']
# Out:
# 0                spray
# 1            audifonos
# 2              plancha
# 3            rastrillo
# 4      chaleco de peso
#             ...
# 995         aftershave
# 996           secadora
# 997            tequila
# 998          cubiertos
# 999         depiladora
# Name: Productos, Length: 1000, dtype: object

# %%
new[['Precio', 'Productos']]
# Out:
#      Precio        Productos
# 0     74.69            spray
# 1     15.28        audifonos
# 2     46.33          plancha
# 3     58.22        rastrillo
# 4     86.31  chaleco de peso
# ..      ...              ...
# 995   40.35       aftershave
# 996   97.38         secadora
# 997   31.84          tequila
# 998   65.82        cubiertos
# 999   88.34       depiladora
#
# [1000 rows x 2 columns]

# %%
new
# Out:
#          Fecha  Hora  transacciones               Categoria  Precio  Cantidad  \
# 0   2019-01-05    13              0       Health and beauty   74.69         7
# 1   2019-03-08    10              1  Electronic accessories   15.28         5
# 2   2019-03-03    13              2      Home and lifestyle   46.33         7
# 3   2019-01-27    20              3       Health and beauty   58.22         8
# 4   2019-02-08    10              4       Sports and travel   86.31         7
# ..         ...   ...            ...                     ...     ...       ...
# 995 2019-01-29    13            995       Health and beauty   40.35         1
# 996 2019-03-02    17            996      Home and lifestyle   97.38        10
# 997 2019-02-09    13            997      Food and beverages   31.84         1
# 998 2019-02-22    15            998      Home and lifestyle   65.82         1
# 999 2019-02-18    13            999     Fashion accessories   88.34         7
#
#       Total        Productos       Dia
# 0    522.83            spray  Saturday
# 1     76.40        audifonos    Friday
# 2    324.31          plancha    Sunday
# 3    465.76        rastrillo    Sunday
# 4    604.17  chaleco de peso    Friday
# ..      ...              ...       ...
# 995   40.35       aftershave   Tuesday
# 996  973.80         secadora  Saturday
# 997   31.84          tequila  Saturday
# 998   65.82        cubiertos    Friday
# 999  618.38       depiladora    Monday
#
# [1000 rows x 9 columns]

# %%
prod_list = list(new.Productos.unique())

# %%
prod_list
# Out:
# ['spray',
#  'audifonos',
#  'plancha',
#  'rastrillo',
#  'chaleco de peso',
#  'pilas',
#  'usb',
#  'esponja',
#  'coctel de frutas',
#  'estuche de belleza',
#  'celular',
#  'soundbar',
#  'jugo verde',
#  'talco',
#  'set de pesas',
#  'chilorio',
#  'refrigerador',
#  'monitor',
#  'aceite corporal',
#  'toallero',
#  'playstation',
#  'arrow grip',
#  'cuchillos',
#  'mascara facial',
#  'cosmetiquera',
#  'pasta',
#  'manicure personal',
#  'pesa rusa',
#  'rodillo de espuma',
#  'galletas',
#  'balon medicinal',
#  'porteria',
#  'mouse pad',
#  'tapete',
#  'cubiertos',
#  'silla',
#  'pull up bar',
#  'cafe',
#  'alexa',
#  'ginebra',
#  'airpods',
#  'harina',
#  'piña',
#  'diademas',
#  'peluca',
#  'radio',
#  'pinzas',
#  'laptop',
#  'tapete yoga',
#  'cafetera',
#  'silla de acampar',
#  'bolsa de esqui',
#  'cera',
#  'polvo traslucido',
#  'blush',
#  'organizador de maquillaje',
#  'mochila',
#  'mate',
#  'bandas cabeza',
#  'arroz',
#  'oculus rift',
#  'bolsa',
#  'repetidor',
#  'bolsa organizadora',
#  'pasta dental',
#  'acondicionador',
#  'frijoles',
#  'pop-up sheets',
#  'mayonesa',
#  'mesa',
#  'hamaca de camping',
#  'set voleyball',
#  'desodorante',
#  'sales',
#  'microfono',
#  'video proyector',
#  'nueces',
#  'abre corchos',
#  'lampara led',
#  'lifting',
#  'teclado',
#  'leche',
#  'gel',
#  'modem',
#  'cuerda de entrenamiento',
#  'wi',
#  'paracaidas entrenador',
#  'paño de algodon',
#  'ollas',
#  'removedor de espinillas',
#  'bolsa de aseo',
#  'ipad',
#  'set herradura',
#  'jabon exfoliante',
#  'tostador',
#  'rueda abdominal',
#  'tapete para ejercicio',
#  'base',
#  'te verde',
#  'aspiradora',
#  'alfombra',
#  'desmaquillante',
#  'horno',
#  'cable fibra optica',
#  'miel de fruta',
#  'harina de coco',
#  'copas',
#  'tetera',
#  'jugo sazonador',
#  'bascuala',
#  'despertador',
#  'vasos',
#  'tablet',
#  'chrome cast',
#  'cargador',
#  'mouse',
#  'xbox',
#  'shampoo',
#  'crema',
#  'gaveta',
#  'whisky',
#  'blu-ray',
#  'extension',
#  'asas',
#  'tienda de campaña',
#  'coca cola',
#  'tequila',
#  'google home',
#  'aftershave',
#  'set de baño',
#  'cacahuates',
#  'depiladora',
#  'sleeping',
#  'apple tv',
#  'pantalla',
#  'auxiliar',
#  'vodka',
#  'toalla',
#  'raqueta',
#  'escalera agilidad',
#  'vinagre',
#  'aceite cocina',
#  'almendra entera',
#  'endulzante',
#  'lona de camping',
#  'lavadora',
#  'hdmi',
#  'home theater',
#  'licor de manzana',
#  'mermelada',
#  'maleta',
#  'secadora']

# %%
productos = pd.DataFrame(columns=['Precio', 'Productos'])

# %%
productos['Productos'] = new.Productos

# %%
lista_prods = list(productos['Productos'].unique())

# %%
v = new['Productos'].drop_duplicates().index

# %%
precio = list(new.Precio.iloc[v])

# %%
new_data= pd.DataFrame(columns=['Producto', 'Precio', 'Cantidad'])

# %%
new_data['Producto'] = new.Productos.iloc[v]

# %%
new_data['Precio'] = precio

# %%
new_data['Cantidad'] = new.Cantidad.iloc[v]

# %%
new_data.to_csv('Prueba_1.csv', index=False)

# %%
new_data
# Out:
#              Producto  Precio  Cantidad
# 0               spray   74.69         7
# 1           audifonos   15.28         5
# 2             plancha   46.33         7
# 3           rastrillo   58.22         8
# 4     chaleco de peso   86.31         7
# ..                ...     ...       ...
# 554      home theater   19.32         7
# 621  licor de manzana   91.61         1
# 643         mermelada   72.52         8
# 796            maleta   60.87         1
# 799          secadora   86.69         5
#
# [152 rows x 3 columns]
